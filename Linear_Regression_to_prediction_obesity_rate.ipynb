# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-3/machine-learning/blob/main/Linear_Regression_to_prediction_obesity_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task : To perform Linear regression on the given data set using python and verify all fundamentals associated with it.
#
# Note : As dataset have not perfect values so below prediction of obesity rate is based on only one Independent variable(In real scenario obesity is depend on multiple factors.like Income,Education,Age,Gender).
# So, In this Obesity Rate is Predicting using Income.

# %%
import numpy as np
import matplotlib.pyplot as plt   #plot something 
import pandas as pd

# %%
from google.colab import drive  #import gogle drive data

# %%
drive.mount('/content/drive') # mount drive data into colab cloud and enter authentication code
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/"My Drive/Colab Notebooks/Dataset Files"
# Out:
# /content/drive/My Drive/Colab Notebooks/Dataset Files

# %%
#Read data from CSV file
dataset=pd.read_csv("Risk_Factor_Surveillance_System.csv",usecols=['Data_Value','Income'])

cleaning_dataset = dataset.dropna()  

dic_inc={"Less than $15,000":1,"$15,000 - $24,999":2,"$25,000 - $34,999":3,"$35,000 - $49,999":4,"$50,000 - $74,999":5,"$75,000 or greater":6,"Data not reported":0}
clean_x = cleaning_dataset['Income'].map(dic_inc)

x_train = clean_x
y_train = cleaning_dataset['Data_Value']    
x1_value = x_train.values.reshape(x_train.size)   # Income (Indpndent Variable)         
y_value = y_train.values.reshape(y_train.size)  # obesity Rate (Dependent Variable)

# %%
#define Hypothesis
#H(x) = theta_array[0] + theta_array[1]*x
def hypothesis(theta_array,x):   # theta_array=[theta_array[0],theta_array[1]]
    return theta_array[0] + theta_array[1]*x

# %%
def cost_function(theta_array,x,y,m):
    total_error=0
    for i in range(m):
        total_error += (theta_array[0]+theta_array[1]*x[i] - y[i])**2
    return total_error/(2*m)

# %%
def gradient_descent(theta_array,x,y,alpha,m):
    summation_0 = 0
    summation_1 = 0
    
    for i in range(m):
        summation_0 = summation_0 + ((theta_array[0]+theta_array[1]*x[i])-y[i])
        summation_1 = summation_1+ ((theta_array[0]+theta_array[1]*x[i])-y[i])*x[i]
    
    new_theta_0 = theta_array[0]-alpha * (summation_0/m)
    new_theta_1 = theta_array[1]-alpha * (summation_1/m)

    updated_theta = [new_theta_0,new_theta_1]
    return updated_theta

# %%
def training(x,y,alpha,iters):
    theta_0 =0
    theta_1 =0
    theta_array = [theta_0,theta_1]

    m=x.size              #size of dataset  
    cost_function_values=[]         

    for i in range(iters):
        theta_array= gradient_descent(theta_array,x,y,alpha,m)

        cost_function_values.append(cost_function(theta_array,x,y,m))
        if(i%2 == 0):
            y_new = x*theta_array[1]+theta_array[0]   #linear regression line equation
            plt.plot(x,y_new,'r')
            plt.scatter(x,y)
            plt.show()

    #Print Cost Function Graph
    x=np.arange(0,len(cost_function_values),step=1)
    plt.plot(x,cost_function_values,"-b")
    plt.xlabel("Number of Iterations")
    plt.ylabel("Cost Value")
    plt.title("Cost Function curve")
    plt.show()
    temp=0

# %%
alpha=0.09
iter=300
training(x1_value,y_value,alpha,iter)

# %% [markdown]
# From above result we can say that It is case of Underfitting....
# So these mthod is not suitable for this type of dataset.
